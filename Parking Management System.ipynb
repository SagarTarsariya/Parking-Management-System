# %%
## import time
import psycopg2
from tabulate import tabulate
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

c = psycopg2.connect(
    host='localhost',
    database='postgres',
    user='postgres',
    password='Sagar@2001')
a=c.cursor()
Vehicle_Number=[]
Vehicle_Type=[]
vehicle_Name=[]
Owner_Name=[]
Date=[]
Time=[]
bikes=100
cars=250

# for login 
while True:
    q = "SELECT*FROM sagar.logindata;"
    a.execute(q)
    datastorage = a.fetchall()
    undata = datastorage[0][0]
    passdata = datastorage[0][1]
    username = input("Enter Username: ")
    password = input("Enter Password: ")
    if username == undata and password == passdata:
        while True:
            print('**********************************************************************************************')
            print("                                  Parking Management System"                                   )
            print('**********************************************************************************************')
            print("                                   1.Vehicle Entry                                            ")
            print("                                   2.Remove Entry                                             ")
            print("                                   3.View Parked Vehicle                                      ")
            print("                                   4.View Left Parking Space                                  ")
            print("                                   5.Amount Details                                           ")
            print("                                   6.Bill                                                     ")
            print("                                   7.Close Programme                                          ")
            print("                                   8.Change Login Credentials                                 ")
            print('**********************************************************************************************')
            
            
            
            ch=int(input("Select option:"))
            #1.Vehicle Entry
            if ch==1:
                no=True
                while no==True:
                    print('-------------------------------------------------------')
                    Vno=input("Enter vehicle number (XXXX-XX-XXXX) - ").upper()
                    if Vno=="":
                        print("---------------Enter Vehicle No.-------------------")
                    elif Vno in Vehicle_Number:
                        print("----------Vehicle Number Already Exists------------")
                    elif len(Vno)==12:
                        no=False
                        Vehicle_Number.append(Vno)
                    else:
                        print("# Enter Valid Vehicle Number #")
                        
                    type=True
                    while type==True and no==False:
                        print('----------------------------------------------------')
                        Vtype=str(input("Enter vehicle type(Bike=A/Car=B):")).lower()
                        if Vtype=="":
                            print("---------------Enter Vehicle Type---------------")
                        elif Vtype=="a":
                            Vehicle_Type.append("Bike")
                            bikes-=1
                            type=False
                        elif Vtype=="b":
                            Vehicle_Type.append("Car")
                            cars-=1
                            type=False
                        else:
                            print("------------Please Enter Valid Option----------")
                            break
                    if Vtype.lower() != "a" and Vtype.lower() != "b":
                        break
                        
                    name=True
                    while name==True and no==False:
                        print('----------------------------')
                        vname=input("Enter vehicle name/model - ")
                        if vname=="":
                            print("------------Please Enter Vehicle Name-----------")
                        else:
                            vehicle_Name.append(vname)
                            name=False
                        
                    o=True
                    while o==True and no==False:
                        print('----------------------------')
                        OName=input("Enter owner name -    ")
                        if OName=="":
                            print("-----------Please Enter Owner Name--------------")
                        else:
                            Owner_Name.append(OName)
                            o=False
                            
                    d=True
                    while d==True and no==False: 
                        query_en1= '''insert into sagar.parked_vehicle values
                                             ('{}','{}','{}','{}',now()::DATE,now()::TIME)'''.format(Vno,Vtype,vname,OName)
                        query_en2= '''insert into sagar.vehicle values
                                    ('{}','{}','{}','{}',now()::DATE,now()::TIME)'''.format(Vno,Vtype,vname,OName)
                        a.execute(query_en1)
                        a.execute(query_en2)
                        c.commit()
                        Time.append(time)
                        d=False
                        print('------------------------------------------------------------------------')
                        print("...........................Record detail saved..........................")
                        print('------------------------------------------------------------------------')
                    no=False
                    break
                    
            #2.Remove Entry
            elif ch==2:
                no=True
                while no==True:
                    Vno=input("\tEnter vehicle number to Delete(XXXX-XX-XXXX) - ").upper()
                    if Vno=="":
                        print("# Enter Vehicle No. #")
                    elif len(Vno)==12:
                        c = psycopg2.connect(
                            host='localhost',
                            database='postgres',
                            user='postgres',
                            password='Sagar@2001')
                        a=c.cursor()
                        query_ex1= '''delete from sagar.parked_vehicle where vehicle_no=('{}')'''.format(Vno)
                        a.execute(query_ex1)
                        c.commit()
                        if Vtype == "a":
                            bikes+=1

                        elif Vtype == "b" :
                            cars+=1
                        if Vno in Vehicle_Number:
                            i=Vehicle_Number.index(Vno)
                            Vehicle_Number.pop(i)
                            Vehicle_Type.pop(i)
                            vehicle_Name.pop(i)
                            Owner_Name.pop(i)
                            no=False
                            print('-----------------------------------------------------------------------')
                            print("............................Removed Sucessfully........................")
                            print('-----------------------------------------------------------------------')
                        elif Vno not in Vehicle_Number:
                            print("# No Such Entry #")
                    
                        else:
                            print("Error")
                    else:
                        print("# Enter Valid Vehicle Number #")
                              
                        
                        
                        
            #3.View Parked Vehicle
            elif ch==3:
                df = pd.read_sql("select * from sagar.parked_vehicle;",c)
                print(tabulate(df,headers="keys", tablefmt="psql",showindex=False))
                
                
                
            #4.View Left Parking Space  
            elif ch==4:
                print('--------------------------------------------------')
                print("Spaces Left For Parking")
                print('--------------------------------------------------')
                print("Spaces Available for Bike - ",bikes)
                print("Spaces Available for Car - ",cars)
                print('--------------------------------------------------')
                
                
                
            #5.Amount Details
            elif ch==5:
                print('--------------------------------------------------')
                print("Parking Rate")
                print('--------------------------------------------------')
                print("*1.Bike         Rs-10")
                print("*2.Car          Rs-20")
                print('--------------------------------------------------')
                
                
                
            #6.Bill
            elif ch==6:
                print('--------------------------------------------------')
                print("................... Generating Bill.....................")
                print('--------------------------------------------------')
                no=True
                while no==True:
                    Vno=input("Enter vehicle number (XXXX-XX-XXXX) - ").upper()
                    if Vno=="":
                        print("# Enter Vehicle No. #")
                    elif len(Vno)==12:
                        if Vno in Vehicle_Number:
                            i=Vehicle_Number.index(Vno)
                            no=False
                        elif Vno not in Vehicle_Number:
                            print("# No Such Entry #")
                            break
                        else:
                            print("Error")
                    else:
                        print("# Enter Valid Vehicle Number #")

                if no != False:
                    continue
                s1=pd.read_sql(f"select entry_time from sagar.parked_vehicle where vehicle_no = '{Vno}' ",c)
                s2=pd.read_sql(f"select entry_date from sagar.parked_vehicle where vehicle_no = '{Vno}' ",c)
                p2=pd.DataFrame(s1)
                p3=pd.DataFrame(s2)
                df2 = p2.to_string(index=False)
                df3 = p3.to_string(index=False)
                print('--------------')
                print(df2)
                print('--------------')
                print(df3)
                print('-------------------------------')
                print("Vehicle Type - ",Vehicle_Type[i])
                print('-------------------------------')
                inp=True
                while inp==True:
                    if Vehicle_Type[i]=="Bike":
                        amt=10 
                        inp=False
                    elif Vehicle_Type[i]=="Car":
                        amt=20
                        inp=False
                    c = psycopg2.connect(
                        host='localhost',
                        database='postgres',
                        user='postgres',
                        password='Sagar@2001')
                    a=c.cursor()
                    query_ex2= '''update sagar.vehicle
                                  set exit_time = now()::TIME, bill_amount = ('{}') where vehicle_no =('{}')'''.format(amt,Vno)
                    a.execute(query_ex2)          
                    c.commit()
                    print('-------------------------------')
                    print("Parking Charge - ",amt)
                    print('-------------------------------')
                print("..............................Thank you for using our service....................")
                a=input("Press Any Key to Proceed - ")
                
                
                
            #7.Close Programme
            elif ch==7:
                print("..............................Thank you for using our service.........................")
                print("                           >---------(: Bye Bye :)--------<                           ") 
                
                
                
            #8.Change Password
            elif ch==8:
                changelogin()
            else:
                print('                                                                                          ')
                print('-----------------------------------Please Select Valid Option-----------------------------')
                print('                                                                                          ')
        break;
    else:
        print('----------------------------')
        print("Invalid Username or Password")
        print('----------------------------')

# %%
def changelogin():   
    while 1:
        q = "SELECT*FROM sagar.logindata;"
        a.execute(q)
        datastorage = a.fetchall()
        undata = datastorage[0][0]
        passdata = datastorage[0][1]
        print('----------------------------')
        data1 = input("Enter Old Username: ")
        print('----------------------------')
        data2 = input("Enter Old Password: ")
        if data1 == undata and data2 == passdata:
            print(">>>------------------------<<<")
            print("Access Granted")
            username = input("Enter New Username: ")
            print(">>>------------------------<<<")
            password = input("Enter New Password: ")
            print(">>>------------------------<<<")
            print("Login Credentials Changed")
            q = a.execute(f"UPDATE sagar.logindata SET username='{username}', password='{password}' WHERE id=1;")
            c.commit()
            break
        else:
            print("Invalid Username or Password")
            break
